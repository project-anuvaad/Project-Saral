# %%
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            rois.append({
                #"annotationId": region['id'],
                "annotationTags": region['tags'][0],
                "extractionMethod": "NUMERIC_CLASSIFICATION",
                "roiId": str(uuid.uuid4()),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup):
    
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""

              cells_data.append({
                          "cellId": str(uuid.uuid4()),
                          "rois": get_rois(regions,tagGroup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": tagGroup.rstrip("_"),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "Odisha SAT Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("sat_up_vottraw.json")
#regions

# %%
tagGroups = ["ROLLNUMBER", "HINDIID1","HINDIID2","HINDIID3","HINDIID4","HINDIID5","HINDIID6","HINDIID7","HINDIID8","HINDIID9","HINDIIDTEN","ENGLISHID1","ENGLISHID2","ENGLISHID3","ENGLISHID4","ENGLISHID5","ENGLISHID6","ENGLISHID7","ENGLISHID8","ENGLISHID9","ENGLISHIDTEN","MATHSID1","MATHSID2","MATHSID3","MATHSID4","MATHSID5","MATHSID6","MATHSID7","MATHSID8","MATHSID9","MATHSIDTEN","EVSID1","EVSID2","EVSID3","EVSID4","EVSID5","EVSID6","EVSID7","EVSID8","EVSID9","EVSIDTEN","SCIENCEID1","SCIENCEID2","SCIENCEID3","SCIENCEID4","SCIENCEID5","SCIENCEID6","SCIENCEID7","SCIENCEID8","SCIENCEID9","SCIENCEIDTEN"]
#rois=get_rois(regions,tagGroups[0])
formatLookup = {
    'HINDIID1':'HINDI 1',
    'HINDIID2':'HINDI 2',
    'HINDIID3':'HINDI 3',
    'HINDIID4':'HINDI 4',
    'HINDIID5':'HINDI 5',
    'HINDIID6':'HINDI 6',
    'HINDIID7':'HINDI 7',
    'HINDIID8':'HINDI 8',
    'HINDIID9':'HINDI 9',
    'HINDIIDTEN':'HINDI 10',
    'ENGLISHID1':'ENGLISH 1',
    'ENGLISHID2':'ENGLISH 2',
    'ENGLISHID3':'ENGLISH 3',
    'ENGLISHID4':'ENGLISH 4',
    'ENGLISHID5':'ENGLISH 5',
    'ENGLISHID6':'ENGLISH 6',
    'ENGLISHID7':'ENGLISH 7',
    'ENGLISHID8':'ENGLISH 8',
    'ENGLISHID9':'ENGLISH 9',
    'ENGLISHIDTEN':'ENGLISH 10',
    'MATHSID1': 'MATHS 1',
    'MATHSID2':'MATHS 2',
    'MATHSID3':'MATHS 3',
    'MATHSID4':'MATHS 4',
    'MATHSID5':'MATHS 5',
    'MATHSID6':'MATHS 6',
    'MATHSID7':'MATHS 7',
    'MATHSID8':'MATHS 8',
    'MATHSID9':'MATHS 9',
    'MATHSIDTEN':'MATHS 10',
    'EVSID1': 'EVS 1',
    'EVSID2':'EVS 2',
    'EVSID3':'EVS 3',
    'EVSID4':'EVS 4',
    'EVSID5':'EVS 5',
    'EVSID6':'EVS 6',
    'EVSID7':'EVS 7',
    'EVSID8':'EVS 8',
    'EVSID9':'EVS 9',
    'EVSIDTEN':'EVS 10',
    'SCIENCEID1': 'SCIENCE 1',
    'SCIENCEID2':'SCIENCE 2',
    'SCIENCEID3':'SCIENCE 3',
    'SCIENCEID4':'SCIENCE 4',
    'SCIENCEID5':'SCIENCE 5',
    'SCIENCEID6':'SCIENCE 6',
    'SCIENCEID7':'SCIENCE 7',
    'SCIENCEID8':'SCIENCE 8',
    'SCIENCEID9':'SCIENCE 9',
    'SCIENCEIDTEN': 'SCIENCE 10'
    
}

# %%
cells=get_cells(regions,tagGroups,formatLookup)

# %% [markdown]
# # pp_json(get_layout(regions,tagGroups),False)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "Odisha SAT Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "a09bcceb-6d96-4dbb-bee4-3bb579399c2c",
#                 "rois": [
#                     {
#                         "annotationTags": "ROLLNUMBER1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "c78bd7ba-9e5b-4476-b0a6-55334441f16f",
#                         "index": 0,
#                         "rect": {
#                             "top": 40,
#                             "left": 155,
#                             "bottom": 73,
#                             "right": 181
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "da86b1b0-ed6e-489a-991d-c9942b56c5cc",
#                         "index": 1,
#                         "rect": {
#                             "top": 41,
#                             "left": 204,
#                             "bottom": 72,
#                             "right": 226
#                         }
#                     },
#                     {
#                         "annotationTags": "ROLLNUMBER3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "a4c7e26a-a78c-41e1-986d-9beaf591616b",
#                         "index": 2,
#                         "rect": {
#                             "top": 41,
#                             "left": 249,
#                             "bottom": 74,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "ROLLNUMBER",
#                     "value": ""
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "80430117-7aa0-4c4c-8193-2732fbcf200b",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8e66b117-b91f-4697-a9c8-763ecf233f13",
#                         "index": 0,
#                         "rect": {
#                             "top": 200,
#                             "left": 155,
#                             "bottom": 235,
#                             "right": 179
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "HINDIID1",
#                     "value": "HINDI 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3a9deb86-d648-4d50-ad5d-247b77594d7c",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "db35f6f7-a4d2-407d-b0a4-5ddc7c0374f8",
#                         "index": 0,
#                         "rect": {
#                             "top": 200,
#                             "left": 202,
#                             "bottom": 235,
#                             "right": 228
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "HINDIID2",
#                     "value": "HINDI 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "160bbbe4-d651-409d-b8b8-488e2e0410fc",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "572df96c-86d7-435a-96a5-715f446e964d",
#                         "index": 0,
#                         "rect": {
#                             "top": 201,
#                             "left": 251,
#                             "bottom": 236,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "HINDIID3",
#                     "value": "HINDI 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "bf028818-da16-42f3-9a5b-c78587992135",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2cfdbb6a-a530-423b-bfc9-1cc4192d96fb",
#                         "index": 0,
#                         "rect": {
#                             "top": 202,
#                             "left": 297,
#                             "bottom": 236,
#                             "right": 324
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "HINDIID4",
#                     "value": "HINDI 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "36cd36c1-5d15-437d-bfca-928116ab6cdf",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "fc2e1e2d-fdce-4b8e-b63d-463883daf32d",
#                         "index": 0,
#                         "rect": {
#                             "top": 200,
#                             "left": 344,
#                             "bottom": 236,
#                             "right": 369
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "HINDIID5",
#                     "value": "HINDI 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "c69bc3d5-66d7-4f4a-899d-d2374dfa9723",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3eee1b30-e46f-4a5b-b0dc-b4cf1eba351d",
#                         "index": 0,
#                         "rect": {
#                             "top": 202,
#                             "left": 392,
#                             "bottom": 236,
#                             "right": 418
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "HINDIID6",
#                     "value": "HINDI 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "07b70032-72b4-4c7e-a947-59df6519e280",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "45276449-096e-46f4-ab1c-6b28a1d5568b",
#                         "index": 0,
#                         "rect": {
#                             "top": 202,
#                             "left": 439,
#                             "bottom": 237,
#                             "right": 464
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "HINDIID7",
#                     "value": "HINDI 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "0c6558d0-8aff-4891-b009-7ddca78f0e08",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "aaf6ada5-c5e0-4971-b7cc-5fc55ed9b08a",
#                         "index": 0,
#                         "rect": {
#                             "top": 201,
#                             "left": 486,
#                             "bottom": 235,
#                             "right": 512
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "HINDIID8",
#                     "value": "HINDI 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3ed623e4-049e-42d3-9e61-297fcb662539",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "26dfcae5-839f-4a08-8dd3-c651add0f32a",
#                         "index": 0,
#                         "rect": {
#                             "top": 201,
#                             "left": 534,
#                             "bottom": 237,
#                             "right": 561
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "HINDIID9",
#                     "value": "HINDI 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "865c2b64-6967-47c3-ab4e-b32b06e4e96e",
#                 "rois": [
#                     {
#                         "annotationTags": "HINDIIDTEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2d3f8850-c4e8-4138-9997-ee19d5392460",
#                         "index": 0,
#                         "rect": {
#                             "top": 202,
#                             "left": 582,
#                             "bottom": 237,
#                             "right": 607
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "HINDIIDTEN",
#                     "value": "HINDI 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "fc88c8c7-0162-428b-832f-c4283b6d16cf",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9ccfef41-4ff8-46d0-8462-c39389c1363e",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 155,
#                             "bottom": 287,
#                             "right": 182
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "ENGLISHID1",
#                     "value": "ENGLISH 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "d6e5fe3c-085a-4088-94fd-9ead0f26569e",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "df9896a4-d3df-4554-a83a-367700838768",
#                         "index": 0,
#                         "rect": {
#                             "top": 254,
#                             "left": 203,
#                             "bottom": 288,
#                             "right": 229
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "ENGLISHID2",
#                     "value": "ENGLISH 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "fd8efd3f-0bdc-4cfe-8092-1dcd792f01a2",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "97cd3ce6-e806-48cb-9e9b-d99149ca65be",
#                         "index": 0,
#                         "rect": {
#                             "top": 254,
#                             "left": 250,
#                             "bottom": 288,
#                             "right": 274
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 14
#                 },
#                 "format": {
#                     "name": "ENGLISHID3",
#                     "value": "ENGLISH 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "ea878ae0-cb26-417a-972a-a84989b31866",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4620a3b6-e48b-4166-befb-b7309b748f4d",
#                         "index": 0,
#                         "rect": {
#                             "top": 255,
#                             "left": 296,
#                             "bottom": 290,
#                             "right": 322
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 15
#                 },
#                 "format": {
#                     "name": "ENGLISHID4",
#                     "value": "ENGLISH 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "ed557318-28de-4515-a576-49f3961ddc59",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "51117dea-9154-47f5-a3af-6d6ce12d7911",
#                         "index": 0,
#                         "rect": {
#                             "top": 255,
#                             "left": 345,
#                             "bottom": 289,
#                             "right": 371
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 16
#                 },
#                 "format": {
#                     "name": "ENGLISHID5",
#                     "value": "ENGLISH 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "eed43480-4c01-417b-bf59-090e5b8b9200",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ad3c7f10-6913-4bdf-bce0-00941e9607bd",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 392,
#                             "bottom": 288,
#                             "right": 416
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 17
#                 },
#                 "format": {
#                     "name": "ENGLISHID6",
#                     "value": "ENGLISH 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2b89fe3e-fd31-4c54-bcc0-25e504d5a517",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f0ba46ae-4aa8-401e-b91c-3a58228533aa",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 439,
#                             "bottom": 289,
#                             "right": 466
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 18
#                 },
#                 "format": {
#                     "name": "ENGLISHID7",
#                     "value": "ENGLISH 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "7b72fb8b-414c-4f15-a95f-49d74fe5f14f",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "a8052a9d-10ea-47de-9ad2-b95899e8cdd5",
#                         "index": 0,
#                         "rect": {
#                             "top": 254,
#                             "left": 488,
#                             "bottom": 288,
#                             "right": 513
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 19
#                 },
#                 "format": {
#                     "name": "ENGLISHID8",
#                     "value": "ENGLISH 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "05b6262b-ebba-4c9a-870d-423356c8fea2",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "45ebaf26-96b0-4f86-8034-b362c57b0ae3",
#                         "index": 0,
#                         "rect": {
#                             "top": 254,
#                             "left": 535,
#                             "bottom": 289,
#                             "right": 561
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 20
#                 },
#                 "format": {
#                     "name": "ENGLISHID9",
#                     "value": "ENGLISH 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "682aebbc-eee2-4055-84df-02cea688e05a",
#                 "rois": [
#                     {
#                         "annotationTags": "ENGLISHIDTEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e7c7338a-c180-439b-8f39-fc7d5080c0b6",
#                         "index": 0,
#                         "rect": {
#                             "top": 254,
#                             "left": 583,
#                             "bottom": 289,
#                             "right": 608
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 21
#                 },
#                 "format": {
#                     "name": "ENGLISHIDTEN",
#                     "value": "ENGLISH 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5c52a3ee-cc6b-4126-a30a-e210338b8064",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e27e54dc-1ffc-4039-93cb-05847c3776c2",
#                         "index": 0,
#                         "rect": {
#                             "top": 304,
#                             "left": 155,
#                             "bottom": 340,
#                             "right": 179
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 22
#                 },
#                 "format": {
#                     "name": "MATHSID1",
#                     "value": "MATHS 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "a6232fba-fc1a-4823-b1ba-7d8a6c004f6d",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ca7fc680-3839-4c6b-9a68-1d10bfb90e59",
#                         "index": 0,
#                         "rect": {
#                             "top": 306,
#                             "left": 203,
#                             "bottom": 339,
#                             "right": 229
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 23
#                 },
#                 "format": {
#                     "name": "MATHSID2",
#                     "value": "MATHS 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "b9a27cef-1309-420b-86b8-a05cf7d8eca0",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2a8be8ce-b47f-4190-8182-b44e6b9a976f",
#                         "index": 0,
#                         "rect": {
#                             "top": 306,
#                             "left": 252,
#                             "bottom": 339,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 24
#                 },
#                 "format": {
#                     "name": "MATHSID3",
#                     "value": "MATHS 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "a9ad7a89-ca92-4c53-9dc9-5f311bdf30dc",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "12e286db-ac91-402d-bacb-85724ecac590",
#                         "index": 0,
#                         "rect": {
#                             "top": 306,
#                             "left": 299,
#                             "bottom": 341,
#                             "right": 323
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 25
#                 },
#                 "format": {
#                     "name": "MATHSID4",
#                     "value": "MATHS 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "231f0bb8-6b7b-46ab-a9a2-b2e13b7b42f9",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e5844b8d-5626-443f-a743-2ad58dc1560b",
#                         "index": 0,
#                         "rect": {
#                             "top": 308,
#                             "left": 345,
#                             "bottom": 341,
#                             "right": 371
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 26
#                 },
#                 "format": {
#                     "name": "MATHSID5",
#                     "value": "MATHS 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4641d541-118a-4e7e-8ee9-e369cd95f625",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b93ef447-643b-42de-90d6-c2b45ab07697",
#                         "index": 0,
#                         "rect": {
#                             "top": 308,
#                             "left": 392,
#                             "bottom": 343,
#                             "right": 418
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 27
#                 },
#                 "format": {
#                     "name": "MATHSID6",
#                     "value": "MATHS 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "47dd70fe-ec08-4253-a1e3-8a18c7eecf74",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3a7cff27-edab-4d16-976b-94d11b8b4fcd",
#                         "index": 0,
#                         "rect": {
#                             "top": 308,
#                             "left": 440,
#                             "bottom": 343,
#                             "right": 466
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 28
#                 },
#                 "format": {
#                     "name": "MATHSID7",
#                     "value": "MATHS 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "907d8941-0ff3-4eaf-8ec9-d8e091303a5e",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "66b2ce53-c108-4e24-a324-4aa47117c4cd",
#                         "index": 0,
#                         "rect": {
#                             "top": 306,
#                             "left": 487,
#                             "bottom": 343,
#                             "right": 513
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 29
#                 },
#                 "format": {
#                     "name": "MATHSID8",
#                     "value": "MATHS 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "f2d712a5-b812-4d86-b517-a64acaaf6e2f",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3553fecf-b98b-4f47-bf1b-188ef7e218d9",
#                         "index": 0,
#                         "rect": {
#                             "top": 308,
#                             "left": 534,
#                             "bottom": 343,
#                             "right": 563
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 30
#                 },
#                 "format": {
#                     "name": "MATHSID9",
#                     "value": "MATHS 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "dfa3beac-93a4-4081-bae5-6b9b900fa568",
#                 "rois": [
#                     {
#                         "annotationTags": "MATHSIDTEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "de145371-dd64-4f78-bf06-dec81fc255ff",
#                         "index": 0,
#                         "rect": {
#                             "top": 308,
#                             "left": 584,
#                             "bottom": 341,
#                             "right": 610
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 31
#                 },
#                 "format": {
#                     "name": "MATHSIDTEN",
#                     "value": "MATHS 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "545a79fc-db9c-4b22-8ba1-570d4f625eaf",
#                 "rois": [
#                     {
#                         "annotationTags": "EVSID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "30e7dfa9-f4be-4fad-bc64-d6b181701045",
#                         "index": 0,
#                         "rect": {
#                             "top": 359,
#                             "left": 155,
#                             "bottom": 394,
#                             "right": 181
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 32
#                 },
#                 "format": {
#                     "name": "EVSID1",
#                     "value": "EVS 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "6657250c-5464-4304-adaf-b1217c2e49ec",
#                 "rois": [
#                     {
#                         "annotationTags": "EVSID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4acc2449-fb7d-4f6c-86f0-36e2e852678b",
#                         "index": 0,
#                         "rect": {
#                             "top": 358,
#                             "left": 203,
#                             "bottom": 395,
#                             "right": 229
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 33
#                 },
#                 "format": {
#                     "name": "EVSID2",
#                     "value": "EVS 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "f1cf9541-9806-4996-836d-622a8cbd28ca",
#                 "rois": [
#                     {
#                         "annotationTags": "EVSID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7e0cb345-5c78-4036-9d1b-5cb4397a1bce",
#                         "index": 0,
#                         "rect": {
#                             "top": 357,
#                             "left": 251,
#                             "bottom": 393,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 34
#                 },
#                 "format": {
#                     "name": "EVSID3",
#                     "value": "EVS 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9d5d8fba-708f-4d09-beba-940a2bdfa0a9",
#                 "rois": [
#                     {
#                         "annotationTags": "EVSID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d100314d-c7e8-4785-a878-773ce8597deb",
#                         "index": 0,
#                         "rect": {
#                             "top": 359,
#                             "left": 298,
#                             "bottom": 395,
#                             "right": 322
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 35
#                 },
#                 "format": {
#                     "name": "EVSID4",
#                     "value": "EVS 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "c93f70c5-8a65-4034-bf5d-17879b69e3a3",
#                 "rois": [
#                     {
#                         "annotationTags": "EVSID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "c8bec5fd-7c05-4117-a83e-fcdd13d108e7",
#                         "index": 0,
#                         "rect": {
#                             "top": 359,
#                             "left": 345,
#                             "bottom": 395,
#                             "right": 372
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 36
#                 },
#                 "format": {
#                     "name": "EVSID5",
#                     "value": "EVS 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "e77f73d4-5e55-445f-8c77-193de5b3a8d9",
#                 "rois": [
#                     {
#                         "annotationTags": "EVSID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d179e45d-4934-49c2-840c-c753201c0dcc",
#                         "index": 0,
#                         "rect": {
#                             "top": 359,
#                             "left": 393,
#                             "bottom": 394,
#                             "right": 417
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 37
#                 },
#                 "format": {
#                     "name": "EVSID6",
#                     "value": "EVS 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "fb6027fa-e8c0-4f75-9808-859c4f7cee5f",
#                 "rois": [
#                     {
#                         "annotationTags": "EVSID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "06c11050-9f13-46d8-b911-a6d396997544",
#                         "index": 0,
#                         "rect": {
#                             "top": 360,
#                             "left": 441,
#                             "bottom": 396,
#                             "right": 465
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 38
#                 },
#                 "format": {
#                     "name": "EVSID7",
#                     "value": "EVS 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "b7b1e407-a3cf-4cc4-a014-ce6b42b3d03a",
#                 "rois": [
#                     {
#                         "annotationTags": "EVSID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4784e869-5a42-4483-bee3-2893cc900c0f",
#                         "index": 0,
#                         "rect": {
#                             "top": 359,
#                             "left": 489,
#                             "bottom": 394,
#                             "right": 513
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 39
#                 },
#                 "format": {
#                     "name": "EVSID8",
#                     "value": "EVS 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5bab76f7-49e4-4b4d-a3b0-6bd0a8cdd520",
#                 "rois": [
#                     {
#                         "annotationTags": "EVSID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "77da1f8f-47c0-49da-b446-3dbb021431f2",
#                         "index": 0,
#                         "rect": {
#                             "top": 361,
#                             "left": 534,
#                             "bottom": 394,
#                             "right": 562
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 40
#                 },
#                 "format": {
#                     "name": "EVSID9",
#                     "value": "EVS 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "60c18970-d141-485f-a023-24593226fe2a",
#                 "rois": [
#                     {
#                         "annotationTags": "EVSIDTEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2c60ff8a-111e-4559-8d55-609fa8050b36",
#                         "index": 0,
#                         "rect": {
#                             "top": 360,
#                             "left": 582,
#                             "bottom": 394,
#                             "right": 610
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 41
#                 },
#                 "format": {
#                     "name": "EVSIDTEN",
#                     "value": "EVS 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "d791c689-c538-4b0c-ad06-78fd199a90c7",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ea544b4e-a650-4773-8f6d-79599e81e9c4",
#                         "index": 0,
#                         "rect": {
#                             "top": 413,
#                             "left": 155,
#                             "bottom": 448,
#                             "right": 182
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 42
#                 },
#                 "format": {
#                     "name": "SCIENCEID1",
#                     "value": "SCIENCE 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "cf49879b-9840-4f8c-9028-dbfa63179f6c",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "411951f2-68c3-425e-934f-bff9c65aefd4",
#                         "index": 0,
#                         "rect": {
#                             "top": 411,
#                             "left": 202,
#                             "bottom": 449,
#                             "right": 230
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 43
#                 },
#                 "format": {
#                     "name": "SCIENCEID2",
#                     "value": "SCIENCE 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "515db9be-b733-4d06-9d7c-4575c29f8f98",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "598a4968-4d6b-449f-99df-c152afb7a3e7",
#                         "index": 0,
#                         "rect": {
#                             "top": 411,
#                             "left": 251,
#                             "bottom": 447,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 44
#                 },
#                 "format": {
#                     "name": "SCIENCEID3",
#                     "value": "SCIENCE 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "8467fefd-176a-4478-9ee2-2390fd1cba87",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7e69a5ca-5263-4954-be7a-143009e5be91",
#                         "index": 0,
#                         "rect": {
#                             "top": 411,
#                             "left": 298,
#                             "bottom": 448,
#                             "right": 324
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 45
#                 },
#                 "format": {
#                     "name": "SCIENCEID4",
#                     "value": "SCIENCE 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "56a66ddb-a607-407b-9a9c-4cef9ef934b0",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "498bc192-de77-4bf6-9050-ba2ade0ed175",
#                         "index": 0,
#                         "rect": {
#                             "top": 411,
#                             "left": 346,
#                             "bottom": 447,
#                             "right": 370
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 46
#                 },
#                 "format": {
#                     "name": "SCIENCEID5",
#                     "value": "SCIENCE 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "1ed4db7a-dca5-4a67-8e5f-77f2df0c9010",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d4196712-b454-44b0-a16e-ae3d16ece4c3",
#                         "index": 0,
#                         "rect": {
#                             "top": 412,
#                             "left": 393,
#                             "bottom": 448,
#                             "right": 419
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 47
#                 },
#                 "format": {
#                     "name": "SCIENCEID6",
#                     "value": "SCIENCE 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "13064e5c-bce2-4909-9b8b-72a95c6af178",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "c6702c66-03af-43f2-8eb7-be90025a78b1",
#                         "index": 0,
#                         "rect": {
#                             "top": 411,
#                             "left": 439,
#                             "bottom": 447,
#                             "right": 466
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 48
#                 },
#                 "format": {
#                     "name": "SCIENCEID7",
#                     "value": "SCIENCE 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "cc9d2092-dc00-4d58-a499-d4896e48dbd7",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8c6de7a2-2bed-41e5-ab13-ae53f5de2347",
#                         "index": 0,
#                         "rect": {
#                             "top": 412,
#                             "left": 488,
#                             "bottom": 446,
#                             "right": 515
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 49
#                 },
#                 "format": {
#                     "name": "SCIENCEID8",
#                     "value": "SCIENCE 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "a09f1b5e-9bc3-4cc3-a04c-bd93e6ebf1fa",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEID9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6edd3663-99a3-478e-9daa-00ee09352175",
#                         "index": 0,
#                         "rect": {
#                             "top": 413,
#                             "left": 536,
#                             "bottom": 445,
#                             "right": 562
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 50
#                 },
#                 "format": {
#                     "name": "SCIENCEID9",
#                     "value": "SCIENCE 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "1dbad500-9642-4446-9e5a-7b3e4829e799",
#                 "rois": [
#                     {
#                         "annotationTags": "SCIENCEIDTEN",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "0b7290a8-26ce-4684-becf-4a8cb860a01b",
#                         "index": 0,
#                         "rect": {
#                             "top": 412,
#                             "left": 582,
#                             "bottom": 447,
#                             "right": 607
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 51
#                 },
#                 "format": {
#                     "name": "SCIENCEIDTEN",
#                     "value": "SCIENCE 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
