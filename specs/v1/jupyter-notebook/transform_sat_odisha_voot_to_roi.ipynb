# %%
# Dileep Gadiraju - Odisha ROI Transformation from VoTT Raw format
# Takes filename of VoTT raw format file and generates ROI configuration
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            rois.append({
                #"annotationId": region['id'],
                "annotationTags": region['tags'][0],
                "extractionMethod": "NUMERIC_CLASSIFICATION",
                "roiId": str(uuid.uuid4()),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup):
    
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""

              cells_data.append({
                          "cellId": str(uuid.uuid4()),
                          "rois": get_rois(regions,tagGroup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": tagGroup.rstrip("_"),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "Odisha SAT Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("sat_odisha_vottraw.json")

# %%
tagGroups = ["STUDENTID_", "QUESTION1_", "QUESTION2_","QUESTION3_","QUESTION4_","QUESTION5_","QUESTION6_","QUESTION7_","QUESTION8_","QUESTION9_","QUESTION10_","QUESTION11_","QUESTION12_","QUESTION13_","QUESTION14_","QUESTION15_","QUESTION16_","QUESTION17_","QUESTION18_","QUESTION19_","QUESTION20_","MAX_MARKS_","MARKS_OBTAINED_"]
formatLookup = {
    'QUESTION1_':'QUESTION 1',
    'QUESTION2_':'QUESTION 2',
    'QUESTION3_':'QUESTION 3',
    'QUESTION4_':'QUESTION 4',
    'QUESTION5_':'QUESTION 5',
    'QUESTION6_':'QUESTION 6',
    'QUESTION7_':'QUESTION 7',
    'QUESTION8_':'QUESTION 8',
    'QUESTION9_':'QUESTION 9',
    'QUESTION10_':'QUESTION 10',
    'QUESTION11_':'QUESTION 11',
    'QUESTION12_':'QUESTION 12',
    'QUESTION13_':'QUESTION 13',
    'QUESTION14_':'QUESTION 14',
    'QUESTION15_':'QUESTION 15',
    'QUESTION16_':'QUESTION 16',
    'QUESTION17_':'QUESTION 17',
    'QUESTION18_':'QUESTION 18',
    'QUESTION19_':'QUESTION 19',
    'QUESTION20_':'QUESTION 20',
    'STUDENTID_': 'STUDENTID',
    'MAX_MARKS_': 'MAX MARKS',
    'MARKS_OBTAINED_': 'MARKS OBTAINED'
    
}

# %%
cells=get_cells(regions,tagGroups,formatLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "Odisha SAT Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "c0f795c2-bfc0-4bf6-a5f4-3fcc4c5aa2d2",
#                 "rois": [
#                     {
#                         "annotationTags": "STUDENTID_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f4ae67ef-5eaa-4194-9045-ff55c5533662",
#                         "index": 0,
#                         "rect": {
#                             "top": 30,
#                             "left": 192,
#                             "bottom": 50,
#                             "right": 210
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "46682c66-a210-42b1-b611-a61500b56f7e",
#                         "index": 1,
#                         "rect": {
#                             "top": 29,
#                             "left": 215,
#                             "bottom": 51,
#                             "right": 238
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "43af8a30-5ea0-4536-8f2b-8c3cda15cac0",
#                         "index": 2,
#                         "rect": {
#                             "top": 30,
#                             "left": 242,
#                             "bottom": 50,
#                             "right": 265
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "470521af-a3ce-47d3-8b78-8d90e236380f",
#                         "index": 3,
#                         "rect": {
#                             "top": 30,
#                             "left": 269,
#                             "bottom": 49,
#                             "right": 291
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3dfd07ec-d3d6-43e4-aed0-8b1d9607e770",
#                         "index": 4,
#                         "rect": {
#                             "top": 31,
#                             "left": 294,
#                             "bottom": 50,
#                             "right": 315
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9139f8bb-428a-451a-937a-0bc70dbc0a66",
#                         "index": 5,
#                         "rect": {
#                             "top": 31,
#                             "left": 319,
#                             "bottom": 49,
#                             "right": 340
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "54779cc7-26f8-4a6b-803b-2ba84bcd18de",
#                         "index": 6,
#                         "rect": {
#                             "top": 31,
#                             "left": 344,
#                             "bottom": 50,
#                             "right": 367
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "97839dbf-e6b6-43b3-8142-2cbd5d64ace6",
#                         "index": 7,
#                         "rect": {
#                             "top": 31,
#                             "left": 371,
#                             "bottom": 50,
#                             "right": 392
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ee89bb63-e34a-4ad1-9c65-511a34de2320",
#                         "index": 8,
#                         "rect": {
#                             "top": 31,
#                             "left": 395,
#                             "bottom": 50,
#                             "right": 417
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_10",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4b63b405-7c3a-417a-b9ed-900f301058ff",
#                         "index": 9,
#                         "rect": {
#                             "top": 31,
#                             "left": 421,
#                             "bottom": 50,
#                             "right": 442
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_11",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "67b367bb-e907-4ca3-afa9-80fb247ffb62",
#                         "index": 10,
#                         "rect": {
#                             "top": 31,
#                             "left": 446,
#                             "bottom": 50,
#                             "right": 468
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_12",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b48e2a50-42e1-40d6-a122-14c1354eca78",
#                         "index": 11,
#                         "rect": {
#                             "top": 30,
#                             "left": 472,
#                             "bottom": 48,
#                             "right": 494
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_13",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9ea9e655-a341-4ac5-9108-4ce68b05294c",
#                         "index": 12,
#                         "rect": {
#                             "top": 30,
#                             "left": 498,
#                             "bottom": 51,
#                             "right": 519
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_14",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "88c4e363-bf93-49c2-8a93-18107b659f14",
#                         "index": 13,
#                         "rect": {
#                             "top": 31,
#                             "left": 522,
#                             "bottom": 51,
#                             "right": 544
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_15",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "a33131ad-e5f4-4959-947a-70ab2fe159a0",
#                         "index": 14,
#                         "rect": {
#                             "top": 31,
#                             "left": 548,
#                             "bottom": 51,
#                             "right": 570
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_16",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "45c6333c-9bb6-4464-9693-28013da27781",
#                         "index": 15,
#                         "rect": {
#                             "top": 30,
#                             "left": 573,
#                             "bottom": 50,
#                             "right": 596
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "STUDENTID",
#                     "value": "STUDENTID"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "835842cf-787e-4e1c-acf3-38d9b2041f6a",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6fa124e7-c34a-4e32-9362-2a3315f656e7",
#                         "index": 0,
#                         "rect": {
#                             "top": 96,
#                             "left": 215,
#                             "bottom": 115,
#                             "right": 238
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "0bc56d62-1ba2-437f-9d77-624d34df2a42",
#                         "index": 1,
#                         "rect": {
#                             "top": 97,
#                             "left": 252,
#                             "bottom": 117,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "QUESTION1",
#                     "value": "QUESTION 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "64da3f26-66c9-4d1f-ae54-abada953eb2b",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "1dda37ad-8d5b-495a-93fa-2fb4813f16c6",
#                         "index": 0,
#                         "rect": {
#                             "top": 128,
#                             "left": 216,
#                             "bottom": 147,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "33ded682-788c-4b01-96da-da5bb955c87c",
#                         "index": 1,
#                         "rect": {
#                             "top": 128,
#                             "left": 253,
#                             "bottom": 148,
#                             "right": 275
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "QUESTION2",
#                     "value": "QUESTION 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "dea65b63-8907-4970-a5ac-95589ae90514",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION3_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b20c0584-eabe-4144-80c9-0e257984e662",
#                         "index": 0,
#                         "rect": {
#                             "top": 158,
#                             "left": 216,
#                             "bottom": 179,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION3_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5de2929a-292a-47b6-92e1-13dbb7d3b91d",
#                         "index": 1,
#                         "rect": {
#                             "top": 159,
#                             "left": 254,
#                             "bottom": 179,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "QUESTION3",
#                     "value": "QUESTION 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "01a1b9b5-f389-4297-93fa-5962e821ee2a",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION4_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d5719079-9566-4639-ad90-ba9b3e431ff8",
#                         "index": 0,
#                         "rect": {
#                             "top": 191,
#                             "left": 215,
#                             "bottom": 211,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION4_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "df17dcf1-5438-4e5d-b1d3-bcb7b23bf50c",
#                         "index": 1,
#                         "rect": {
#                             "top": 190,
#                             "left": 254,
#                             "bottom": 211,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "QUESTION4",
#                     "value": "QUESTION 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "e236eac5-fc73-4f2d-8703-82f60a6e594b",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION5_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f92d9f58-2e07-4872-8a91-62cdf6802979",
#                         "index": 0,
#                         "rect": {
#                             "top": 221,
#                             "left": 217,
#                             "bottom": 241,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION5_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ddf96e70-3ecb-460d-a0ce-c34dcc1d39b3",
#                         "index": 1,
#                         "rect": {
#                             "top": 221,
#                             "left": 254,
#                             "bottom": 240,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "QUESTION5",
#                     "value": "QUESTION 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "f8994019-c8df-4386-ad3c-d4d478dd2e91",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION6_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6a9c9733-f67f-4aa5-a535-39f8119dd807",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 216,
#                             "bottom": 272,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION6_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8d580367-b075-4f0c-ae70-94439d060dea",
#                         "index": 1,
#                         "rect": {
#                             "top": 252,
#                             "left": 255,
#                             "bottom": 272,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "QUESTION6",
#                     "value": "QUESTION 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "4731eaa7-5794-4d16-83e9-1d8f243f33d7",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION7_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7a982734-503a-48f6-8916-9ed3319ed51a",
#                         "index": 0,
#                         "rect": {
#                             "top": 284,
#                             "left": 217,
#                             "bottom": 304,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION7_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "77bb74e7-9704-4ca7-b317-701ae6a69d4d",
#                         "index": 1,
#                         "rect": {
#                             "top": 282,
#                             "left": 255,
#                             "bottom": 303,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "QUESTION7",
#                     "value": "QUESTION 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "f25b5b2f-521f-46a5-a55d-b3ee01d66489",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION8_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "01e3761a-ad25-45e7-8019-d905762a7296",
#                         "index": 0,
#                         "rect": {
#                             "top": 315,
#                             "left": 216,
#                             "bottom": 333,
#                             "right": 238
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION8_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "fe4e40bf-bed8-48ef-a941-08a8d15af58d",
#                         "index": 1,
#                         "rect": {
#                             "top": 314,
#                             "left": 254,
#                             "bottom": 334,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "QUESTION8",
#                     "value": "QUESTION 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "a98e639a-492e-417a-8613-09d093a3b1be",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION9_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4d00fae5-ca6f-42d5-abb0-30871fb110e7",
#                         "index": 0,
#                         "rect": {
#                             "top": 346,
#                             "left": 217,
#                             "bottom": 364,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION9_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b46a29b6-4773-4b61-9ffc-d1bfd2bfbdf6",
#                         "index": 1,
#                         "rect": {
#                             "top": 346,
#                             "left": 254,
#                             "bottom": 365,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "QUESTION9",
#                     "value": "QUESTION 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "857abbf8-f02e-4ce8-8e3e-d15a9412f5a6",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION10_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9b13e2d7-3c58-4bb2-a420-727237d3a146",
#                         "index": 0,
#                         "rect": {
#                             "top": 378,
#                             "left": 217,
#                             "bottom": 396,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION10_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "4521d2ac-aca7-4591-be7c-d4f71d6eb106",
#                         "index": 1,
#                         "rect": {
#                             "top": 378,
#                             "left": 254,
#                             "bottom": 396,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "QUESTION10",
#                     "value": "QUESTION 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "2860bf06-da09-434a-b076-eca7a00ba483",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION11_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "c792e03b-6e30-4334-8435-ca0e88c64541",
#                         "index": 0,
#                         "rect": {
#                             "top": 96,
#                             "left": 512,
#                             "bottom": 115,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION11_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ec74f024-eecf-41ad-a56a-039a39cc7d33",
#                         "index": 1,
#                         "rect": {
#                             "top": 97,
#                             "left": 550,
#                             "bottom": 115,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "QUESTION11",
#                     "value": "QUESTION 11"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "dababe76-e29a-4f02-af26-bafe5812fb35",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION12_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ab0a223b-241d-41fb-a671-dcfdf791a0f8",
#                         "index": 0,
#                         "rect": {
#                             "top": 129,
#                             "left": 512,
#                             "bottom": 148,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION12_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9695d107-c8d7-4981-85d4-639e5e8a7393",
#                         "index": 1,
#                         "rect": {
#                             "top": 128,
#                             "left": 551,
#                             "bottom": 147,
#                             "right": 572
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "QUESTION12",
#                     "value": "QUESTION 12"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "575a17ef-e7ad-4aee-8e38-12731e8699a8",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION13_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5cbd1ede-5d9a-4d42-9b97-fe6fde01bf54",
#                         "index": 0,
#                         "rect": {
#                             "top": 160,
#                             "left": 512,
#                             "bottom": 178,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION13_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "a6d79923-68b6-4b88-b849-7822fee6398d",
#                         "index": 1,
#                         "rect": {
#                             "top": 160,
#                             "left": 550,
#                             "bottom": 177,
#                             "right": 572
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 14
#                 },
#                 "format": {
#                     "name": "QUESTION13",
#                     "value": "QUESTION 13"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "310615ef-4a16-41ee-9e25-023bff2d541f",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION14_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e00be271-4790-4d58-adff-59801cc6c74c",
#                         "index": 0,
#                         "rect": {
#                             "top": 191,
#                             "left": 511,
#                             "bottom": 210,
#                             "right": 533
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION14_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "88d08b82-c48f-41bc-b174-16bcb8301a67",
#                         "index": 1,
#                         "rect": {
#                             "top": 190,
#                             "left": 549,
#                             "bottom": 210,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 15
#                 },
#                 "format": {
#                     "name": "QUESTION14",
#                     "value": "QUESTION 14"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5a806c5d-09cc-4b08-87bc-a3facf7030c4",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION15_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6b4b283b-11e9-4880-8735-51d3498fba09",
#                         "index": 0,
#                         "rect": {
#                             "top": 222,
#                             "left": 511,
#                             "bottom": 240,
#                             "right": 532
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION15_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "aa59c8a8-863f-4a8a-aeb1-eb4ebbde8a1e",
#                         "index": 1,
#                         "rect": {
#                             "top": 222,
#                             "left": 549,
#                             "bottom": 239,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 16
#                 },
#                 "format": {
#                     "name": "QUESTION15",
#                     "value": "QUESTION 15"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "9d49d9f7-c41a-4e8d-9fc5-9cb3c4e3dc03",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION16_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3c117f4e-efad-4657-93ae-f79e4f318dab",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 511,
#                             "bottom": 272,
#                             "right": 532
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION16_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "02509bd9-0222-4582-8a3d-5a79e9dfadaa",
#                         "index": 1,
#                         "rect": {
#                             "top": 253,
#                             "left": 549,
#                             "bottom": 272,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 17
#                 },
#                 "format": {
#                     "name": "QUESTION16",
#                     "value": "QUESTION 16"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "b051d3ac-68cd-41f0-90fa-1200ab90d116",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION17_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "0bfb5cfb-7311-4841-a3bf-e56a108148aa",
#                         "index": 0,
#                         "rect": {
#                             "top": 284,
#                             "left": 512,
#                             "bottom": 302,
#                             "right": 535
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION17_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8cfef411-595f-47e0-b14e-3d799a707216",
#                         "index": 1,
#                         "rect": {
#                             "top": 284,
#                             "left": 550,
#                             "bottom": 303,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 18
#                 },
#                 "format": {
#                     "name": "QUESTION17",
#                     "value": "QUESTION 17"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "08ed16b4-b533-46b8-9e1e-791739403dcc",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION18_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9af51ebf-8962-439b-b5fe-1ef902098e58",
#                         "index": 0,
#                         "rect": {
#                             "top": 315,
#                             "left": 512,
#                             "bottom": 333,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION18_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "960066f7-c6ee-4b12-9067-f19f39520d43",
#                         "index": 1,
#                         "rect": {
#                             "top": 315,
#                             "left": 550,
#                             "bottom": 334,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 19
#                 },
#                 "format": {
#                     "name": "QUESTION18",
#                     "value": "QUESTION 18"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "769a4ada-5a7d-4260-8d54-281d1772ed99",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION19_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9ebd9117-85b2-4028-bea6-dc606efc3902",
#                         "index": 0,
#                         "rect": {
#                             "top": 346,
#                             "left": 512,
#                             "bottom": 365,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION19_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "216f1cf5-5321-41b8-a60c-d4960680ca5f",
#                         "index": 1,
#                         "rect": {
#                             "top": 347,
#                             "left": 551,
#                             "bottom": 365,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 20
#                 },
#                 "format": {
#                     "name": "QUESTION19",
#                     "value": "QUESTION 19"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "d0b5dfb8-9bf8-4a6e-93eb-9694caf8c183",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION20_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8724a962-9aed-4e97-aca2-a6eb82870237",
#                         "index": 0,
#                         "rect": {
#                             "top": 378,
#                             "left": 512,
#                             "bottom": 396,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION20_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "aaf39dfd-7957-4d54-bfcc-7dd831fc8fcb",
#                         "index": 1,
#                         "rect": {
#                             "top": 377,
#                             "left": 551,
#                             "bottom": 395,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 21
#                 },
#                 "format": {
#                     "name": "QUESTION20",
#                     "value": "QUESTION 20"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "0a01abbf-3dda-4beb-a0ed-018ef93ef2c9",
#                 "rois": [
#                     {
#                         "annotationTags": "MAX_MARKS_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "31af2303-903d-4e34-9c2c-f9314cb73355",
#                         "index": 0,
#                         "rect": {
#                             "top": 430,
#                             "left": 133,
#                             "bottom": 449,
#                             "right": 156
#                         }
#                     },
#                     {
#                         "annotationTags": "MAX_MARKS_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "cfbfe91d-fc20-42df-9177-bf01ba99246d",
#                         "index": 1,
#                         "rect": {
#                             "top": 431,
#                             "left": 159,
#                             "bottom": 450,
#                             "right": 181
#                         }
#                     },
#                     {
#                         "annotationTags": "MAX_MARKS_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e10a4b69-2e24-4bdc-b10d-ca40c3daf4ea",
#                         "index": 2,
#                         "rect": {
#                             "top": 431,
#                             "left": 185,
#                             "bottom": 451,
#                             "right": 207
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 22
#                 },
#                 "format": {
#                     "name": "MAX_MARKS",
#                     "value": "MAX MARKS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "1e958478-3809-4f5d-a3cb-bd9db5625684",
#                 "rois": [
#                     {
#                         "annotationTags": "MARKS_OBTAINED_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b63f4ac0-34da-4fea-9d0d-30366b565029",
#                         "index": 0,
#                         "rect": {
#                             "top": 430,
#                             "left": 333,
#                             "bottom": 449,
#                             "right": 354
#                         }
#                     },
#                     {
#                         "annotationTags": "MARKS_OBTAINED_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f5060c0d-7fe6-4429-b8af-c78c007abc63",
#                         "index": 1,
#                         "rect": {
#                             "top": 430,
#                             "left": 358,
#                             "bottom": 448,
#                             "right": 380
#                         }
#                     },
#                     {
#                         "annotationTags": "MARKS_OBTAINED_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9970b90d-27bd-42ed-88ce-29f6262f1c49",
#                         "index": 2,
#                         "rect": {
#                             "top": 430,
#                             "left": 384,
#                             "bottom": 450,
#                             "right": 405
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 23
#                 },
#                 "format": {
#                     "name": "MARKS_OBTAINED",
#                     "value": "MARKS OBTAINED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
