# %%
# Dileep Gadiraju - Odisha ROI Transformation from VoTT Raw format
# Takes filename of VoTT raw format file and generates ROI configuration
import uuid
import json

roiIndex = 1
cellIndex = 1

def get_annotation(filename):

    with open(filename) as f:
        data = json.load(f)
        f.close()
        return data['regions']

def get_rois(regions,tagGroup):
    rois  = []
    index = 0
    global roiIndex 
    for region in regions:
        if region['tags'][0].startswith(tagGroup):
            rois.append({
                #"annotationId": region['id'],
                "annotationTags": region['tags'][0],
                "extractionMethod": "NUMERIC_CLASSIFICATION",
                "roiId": str(uuid.uuid4()),
                "index": index,
                "rect": {

                    "top": int(region['boundingBox']['top']),

                    "left": int(region['boundingBox']['left']),

                    "bottom": int(region['boundingBox']['top']) + int(region['boundingBox']['height']),

                    "right": int(region['boundingBox']['left']) + int(region['boundingBox']['width'])

                }

            })
            index = index + 1
            roiIndex = roiIndex +1 
        
    return rois

def get_cells(regions,tagGroups,formatLookup):
    
    cells_data = []
    renderIndex = 1
    global cellIndex
    for tagGroup in tagGroups: 
              try:
                  formatValue = formatLookup[str(tagGroup)]
              except KeyError as ke:
                  formatValue = ""

              cells_data.append({
                          "cellId": str(uuid.uuid4()),
                          "rois": get_rois(regions,tagGroup),
                          "render": {
                              "index": renderIndex
                          },
                          "format": {
                              "name": tagGroup.rstrip("_"),
                              "value": formatValue
                          },
                          "validate": {
                              "regExp": ""
                          }
              })
              renderIndex = renderIndex +1   
              cellIndex = cellIndex +1 
    return cells_data

def get_layout(cells):
    layout_data = []
    layout_data.append({
        "layout": {
            "version": "1.0",
            "name": "UP SAT Exam Sheet Form",
            "cells": cells
        }
    })    
    return layout_data[0]

def pp_json(json_thing, sort=True, indents=4):
    if type(json_thing) is str:
        print(json.dumps(json.loads(json_thing), sort_keys=sort, indent=indents))
    else:
        print(json.dumps(json_thing, sort_keys=sort, indent=indents))
    return None

# %%
regions=get_annotation("sat_odisha_vottraw.json")

# %%
tagGroups = ["STUDENTID_", "QUESTION1_", "QUESTION2_","QUESTION3_","QUESTION4_","QUESTION5_","QUESTION6_","QUESTION7_","QUESTION8_","QUESTION9_","QUESTION10_","QUESTION11_","QUESTION12_","QUESTION13_","QUESTION14_","QUESTION15_","QUESTION16_","QUESTION17_","QUESTION18_","QUESTION19_","QUESTION20_","MAX_MARKS_","MARKS_OBTAINED_"]
formatLookup = {
    'QUESTION1_':'QUESTION 1',
    'QUESTION2_':'QUESTION 2',
    'QUESTION3_':'QUESTION 3',
    'QUESTION4_':'QUESTION 4',
    'QUESTION5_':'QUESTION 5',
    'QUESTION6_':'QUESTION 6',
    'QUESTION7_':'QUESTION 7',
    'QUESTION8_':'QUESTION 8',
    'QUESTION9_':'QUESTION 9',
    'QUESTION10_':'QUESTION 10',
    'QUESTION11_':'QUESTION 11',
    'QUESTION12_':'QUESTION 12',
    'QUESTION13_':'QUESTION 13',
    'QUESTION14_':'QUESTION 14',
    'QUESTION15_':'QUESTION 15',
    'QUESTION16_':'QUESTION 16',
    'QUESTION17_':'QUESTION 17',
    'QUESTION18_':'QUESTION 18',
    'QUESTION19_':'QUESTION 19',
    'QUESTION20_':'QUESTION 20',
    'STUDENTID_': 'STUDENTID',
    'MAX_MARKS_': 'MAX MARKS',
    'MARKS_OBTAINED_': 'MARKS OBTAINED'
    
}

# %%
cells=get_cells(regions,tagGroups,formatLookup)

# %%
pp_json(get_layout(cells),False)
# Out:
# {
#     "layout": {
#         "version": "1.0",
#         "name": "UP SAT Exam Sheet Form",
#         "cells": [
#             {
#                 "cellId": "b1a40072-b096-41f6-b630-2915cc909cf2",
#                 "rois": [
#                     {
#                         "annotationTags": "STUDENTID_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "283ba0a3-4e15-4c42-92b9-e03ced358279",
#                         "index": 0,
#                         "rect": {
#                             "top": 30,
#                             "left": 192,
#                             "bottom": 50,
#                             "right": 210
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e9007ded-cba8-42eb-9cd7-e7c704bdbc2c",
#                         "index": 1,
#                         "rect": {
#                             "top": 29,
#                             "left": 215,
#                             "bottom": 51,
#                             "right": 238
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5e7715d4-6542-48d8-95f0-b8bcde4f422b",
#                         "index": 2,
#                         "rect": {
#                             "top": 30,
#                             "left": 242,
#                             "bottom": 50,
#                             "right": 265
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_4",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ce740c33-270f-4454-975d-810af6cf90f4",
#                         "index": 3,
#                         "rect": {
#                             "top": 30,
#                             "left": 269,
#                             "bottom": 49,
#                             "right": 291
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_5",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e3769c0b-ff3d-44d6-aa0e-419607d3594a",
#                         "index": 4,
#                         "rect": {
#                             "top": 31,
#                             "left": 294,
#                             "bottom": 50,
#                             "right": 315
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_6",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "30f7ea84-dc4b-413a-b77c-377ab75cdfe3",
#                         "index": 5,
#                         "rect": {
#                             "top": 31,
#                             "left": 319,
#                             "bottom": 49,
#                             "right": 340
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_7",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "90c1140e-56a1-420a-89d7-8599329c6d67",
#                         "index": 6,
#                         "rect": {
#                             "top": 31,
#                             "left": 344,
#                             "bottom": 50,
#                             "right": 367
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_8",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "fea16961-8c89-449d-b804-a99ff3f4e001",
#                         "index": 7,
#                         "rect": {
#                             "top": 31,
#                             "left": 371,
#                             "bottom": 50,
#                             "right": 392
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_9",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b962229c-78ee-4382-a6d4-456e5c19588d",
#                         "index": 8,
#                         "rect": {
#                             "top": 31,
#                             "left": 395,
#                             "bottom": 50,
#                             "right": 417
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_10",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "44b2d3fb-5f6a-4ec3-bd81-0b4a08a32c43",
#                         "index": 9,
#                         "rect": {
#                             "top": 31,
#                             "left": 421,
#                             "bottom": 50,
#                             "right": 442
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_11",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9d4a392e-dd00-4c1e-a2c0-7d5d4c9f3f0d",
#                         "index": 10,
#                         "rect": {
#                             "top": 31,
#                             "left": 446,
#                             "bottom": 50,
#                             "right": 468
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_12",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "94a3a073-d6ad-417f-b23b-ce1d208c6004",
#                         "index": 11,
#                         "rect": {
#                             "top": 30,
#                             "left": 472,
#                             "bottom": 48,
#                             "right": 494
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_13",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2c5b812d-db72-4bfa-b62d-437e3b177e5c",
#                         "index": 12,
#                         "rect": {
#                             "top": 30,
#                             "left": 498,
#                             "bottom": 51,
#                             "right": 519
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_14",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d590cd76-c201-4b39-a53b-948856dc2c34",
#                         "index": 13,
#                         "rect": {
#                             "top": 31,
#                             "left": 522,
#                             "bottom": 51,
#                             "right": 544
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_15",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "bb5261dc-91d7-4d06-9947-90d012e7a010",
#                         "index": 14,
#                         "rect": {
#                             "top": 31,
#                             "left": 548,
#                             "bottom": 51,
#                             "right": 570
#                         }
#                     },
#                     {
#                         "annotationTags": "STUDENTID_16",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "2fe30058-eae7-49b6-8cf8-c9da73b55151",
#                         "index": 15,
#                         "rect": {
#                             "top": 30,
#                             "left": 573,
#                             "bottom": 50,
#                             "right": 596
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 1
#                 },
#                 "format": {
#                     "name": "STUDENTID",
#                     "value": "STUDENTID"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3ad61175-efc8-432e-aef2-3e028ea19eab",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION1_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "fde607a0-66fc-4a70-9ac5-cee24ad6eab6",
#                         "index": 0,
#                         "rect": {
#                             "top": 96,
#                             "left": 215,
#                             "bottom": 115,
#                             "right": 238
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION1_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b0141d91-b4e9-41a1-82db-ad465a51d07c",
#                         "index": 1,
#                         "rect": {
#                             "top": 97,
#                             "left": 252,
#                             "bottom": 117,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 2
#                 },
#                 "format": {
#                     "name": "QUESTION1",
#                     "value": "QUESTION 1"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "47e4050f-c5c6-4d43-8cba-c9669d4d571d",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION2_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "cc4c9998-361c-48aa-8ffc-5ef90ec1bf96",
#                         "index": 0,
#                         "rect": {
#                             "top": 128,
#                             "left": 216,
#                             "bottom": 147,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION2_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d9351c29-7e10-4048-bfb6-b4d3faf52886",
#                         "index": 1,
#                         "rect": {
#                             "top": 128,
#                             "left": 253,
#                             "bottom": 148,
#                             "right": 275
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 3
#                 },
#                 "format": {
#                     "name": "QUESTION2",
#                     "value": "QUESTION 2"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "528fb308-4976-4125-9354-e74687f21464",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION3_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "65fc8832-85d0-4096-b8fe-6cb1a6f32e8b",
#                         "index": 0,
#                         "rect": {
#                             "top": 158,
#                             "left": 216,
#                             "bottom": 179,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION3_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3511c819-86ad-41a6-9fe0-499c6f3d77d9",
#                         "index": 1,
#                         "rect": {
#                             "top": 159,
#                             "left": 254,
#                             "bottom": 179,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 4
#                 },
#                 "format": {
#                     "name": "QUESTION3",
#                     "value": "QUESTION 3"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "5f82f312-1a93-4f8b-aad1-6d8596dd8719",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION4_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "57cb62d0-7d4c-466a-a7ea-b572ceef95b6",
#                         "index": 0,
#                         "rect": {
#                             "top": 191,
#                             "left": 215,
#                             "bottom": 211,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION4_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "c82057fa-d4b1-4b34-ac58-f4fe435d9140",
#                         "index": 1,
#                         "rect": {
#                             "top": 190,
#                             "left": 254,
#                             "bottom": 211,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 5
#                 },
#                 "format": {
#                     "name": "QUESTION4",
#                     "value": "QUESTION 4"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "819f4b56-eff8-43b4-946b-83154dc5bab8",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION5_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "48a0cd0e-72cc-44d2-b52c-e9acbc541fa1",
#                         "index": 0,
#                         "rect": {
#                             "top": 221,
#                             "left": 217,
#                             "bottom": 241,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION5_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "65361fc9-8f6e-4bf2-a4d7-eaafa03f3ad3",
#                         "index": 1,
#                         "rect": {
#                             "top": 221,
#                             "left": 254,
#                             "bottom": 240,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 6
#                 },
#                 "format": {
#                     "name": "QUESTION5",
#                     "value": "QUESTION 5"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "d0d88018-5e4a-4bc4-9937-d732a229f49a",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION6_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "03578bbf-54b0-4793-8288-dec2d1190142",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 216,
#                             "bottom": 272,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION6_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "cb8702db-5552-4a24-902a-bfdf3c2c9e38",
#                         "index": 1,
#                         "rect": {
#                             "top": 252,
#                             "left": 255,
#                             "bottom": 272,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 7
#                 },
#                 "format": {
#                     "name": "QUESTION6",
#                     "value": "QUESTION 6"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "cfcdb1e2-48a6-40d5-864c-7d915da9e093",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION7_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "38499613-0ae1-4c13-8411-46c7976899be",
#                         "index": 0,
#                         "rect": {
#                             "top": 284,
#                             "left": 217,
#                             "bottom": 304,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION7_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8634e0a1-79c6-4250-b981-7079f3dfcf40",
#                         "index": 1,
#                         "rect": {
#                             "top": 282,
#                             "left": 255,
#                             "bottom": 303,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 8
#                 },
#                 "format": {
#                     "name": "QUESTION7",
#                     "value": "QUESTION 7"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "81c85075-278f-41b2-8b27-7203dada9060",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION8_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "31208153-c59c-4cef-bfc3-a0eed9f927c1",
#                         "index": 0,
#                         "rect": {
#                             "top": 315,
#                             "left": 216,
#                             "bottom": 333,
#                             "right": 238
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION8_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "014e3e86-aa54-4766-ac4f-db5a0388b54c",
#                         "index": 1,
#                         "rect": {
#                             "top": 314,
#                             "left": 254,
#                             "bottom": 334,
#                             "right": 276
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 9
#                 },
#                 "format": {
#                     "name": "QUESTION8",
#                     "value": "QUESTION 8"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "0c2b3a7f-84f0-46d3-803c-5c0652cf30ad",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION9_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "9dbd63ad-97c9-43ba-a5ce-78d10bec0574",
#                         "index": 0,
#                         "rect": {
#                             "top": 346,
#                             "left": 217,
#                             "bottom": 364,
#                             "right": 240
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION9_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3c8bb16c-223f-47f6-ae97-cc6c071f4d62",
#                         "index": 1,
#                         "rect": {
#                             "top": 346,
#                             "left": 254,
#                             "bottom": 365,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 10
#                 },
#                 "format": {
#                     "name": "QUESTION9",
#                     "value": "QUESTION 9"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "43fed111-8666-4298-b9c9-3c566c1837c2",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION10_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "272df785-8435-4dcb-9d42-3c7500d5c87c",
#                         "index": 0,
#                         "rect": {
#                             "top": 378,
#                             "left": 217,
#                             "bottom": 396,
#                             "right": 239
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION10_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "8dd27891-62b0-4aff-9a5c-97ee66beec80",
#                         "index": 1,
#                         "rect": {
#                             "top": 378,
#                             "left": 254,
#                             "bottom": 396,
#                             "right": 277
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 11
#                 },
#                 "format": {
#                     "name": "QUESTION10",
#                     "value": "QUESTION 10"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3e202bd8-87c3-44cf-a6b9-50d3537b14f5",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION11_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7606839f-5b25-4121-8c09-2285b91803ce",
#                         "index": 0,
#                         "rect": {
#                             "top": 96,
#                             "left": 512,
#                             "bottom": 115,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION11_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "b1b066b6-bdd0-42bd-86be-c1ba480f54ee",
#                         "index": 1,
#                         "rect": {
#                             "top": 97,
#                             "left": 550,
#                             "bottom": 115,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 12
#                 },
#                 "format": {
#                     "name": "QUESTION11",
#                     "value": "QUESTION 11"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "3f2f3f31-40e5-4c14-ab4e-0984734af45f",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION12_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "93c314be-71d2-4d7e-9e84-9bf476fc7928",
#                         "index": 0,
#                         "rect": {
#                             "top": 129,
#                             "left": 512,
#                             "bottom": 148,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION12_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "342f75c7-1ef7-466b-aae4-326e5e921905",
#                         "index": 1,
#                         "rect": {
#                             "top": 128,
#                             "left": 551,
#                             "bottom": 147,
#                             "right": 572
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 13
#                 },
#                 "format": {
#                     "name": "QUESTION12",
#                     "value": "QUESTION 12"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "51879e98-88b1-43a8-b09c-74ec037fa12b",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION13_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "afd89a93-f4a9-4517-88df-b1f67051062d",
#                         "index": 0,
#                         "rect": {
#                             "top": 160,
#                             "left": 512,
#                             "bottom": 178,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION13_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "a0332b0b-8e61-4545-9b0f-c827efc5d6f6",
#                         "index": 1,
#                         "rect": {
#                             "top": 160,
#                             "left": 550,
#                             "bottom": 177,
#                             "right": 572
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 14
#                 },
#                 "format": {
#                     "name": "QUESTION13",
#                     "value": "QUESTION 13"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "b540729c-4da1-48df-8655-098dd60fb78e",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION14_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "c7250b2a-00f6-4211-ab37-1829f94c9a9d",
#                         "index": 0,
#                         "rect": {
#                             "top": 191,
#                             "left": 511,
#                             "bottom": 210,
#                             "right": 533
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION14_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5027b4ef-1064-4b33-be13-07bf322b56ee",
#                         "index": 1,
#                         "rect": {
#                             "top": 190,
#                             "left": 549,
#                             "bottom": 210,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 15
#                 },
#                 "format": {
#                     "name": "QUESTION14",
#                     "value": "QUESTION 14"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "c1cbe472-6358-46d8-ae56-87208839140d",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION15_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "14123ad8-f1de-4775-987f-8b386cb08390",
#                         "index": 0,
#                         "rect": {
#                             "top": 222,
#                             "left": 511,
#                             "bottom": 240,
#                             "right": 532
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION15_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "5e94169b-4ea1-4eb3-a285-1941b1ac5c96",
#                         "index": 1,
#                         "rect": {
#                             "top": 222,
#                             "left": 549,
#                             "bottom": 239,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 16
#                 },
#                 "format": {
#                     "name": "QUESTION15",
#                     "value": "QUESTION 15"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "c69d17be-578f-47e8-bb44-2c5281b77503",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION16_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e6751f03-0ee8-4d71-a0de-9b424ff3bd15",
#                         "index": 0,
#                         "rect": {
#                             "top": 253,
#                             "left": 511,
#                             "bottom": 272,
#                             "right": 532
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION16_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "f5e4c1fb-4ffe-459a-8825-9576b038dbad",
#                         "index": 1,
#                         "rect": {
#                             "top": 253,
#                             "left": 549,
#                             "bottom": 272,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 17
#                 },
#                 "format": {
#                     "name": "QUESTION16",
#                     "value": "QUESTION 16"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "b471b105-45fd-4e9a-9a99-c95f185fbe76",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION17_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "07e5d971-598f-4976-98b0-f5613c12c7ed",
#                         "index": 0,
#                         "rect": {
#                             "top": 284,
#                             "left": 512,
#                             "bottom": 302,
#                             "right": 535
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION17_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "bc618908-cb80-463a-bda5-6a932d65b316",
#                         "index": 1,
#                         "rect": {
#                             "top": 284,
#                             "left": 550,
#                             "bottom": 303,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 18
#                 },
#                 "format": {
#                     "name": "QUESTION17",
#                     "value": "QUESTION 17"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "c67aae3c-00fa-4b46-99cc-ed3739e28b28",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION18_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "47800bf5-27d8-430b-8ad4-d047d91b63f7",
#                         "index": 0,
#                         "rect": {
#                             "top": 315,
#                             "left": 512,
#                             "bottom": 333,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION18_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "a19b7ffd-fe6c-4a00-b269-6612aac85214",
#                         "index": 1,
#                         "rect": {
#                             "top": 315,
#                             "left": 550,
#                             "bottom": 334,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 19
#                 },
#                 "format": {
#                     "name": "QUESTION18",
#                     "value": "QUESTION 18"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "d4c802e9-539f-4fa0-8894-d7663968bc99",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION19_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "6d56cc40-30d9-43cb-bc8d-4b98a7ec6883",
#                         "index": 0,
#                         "rect": {
#                             "top": 346,
#                             "left": 512,
#                             "bottom": 365,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION19_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "0c1185ad-0478-42ca-b60c-aab37fb4d54a",
#                         "index": 1,
#                         "rect": {
#                             "top": 347,
#                             "left": 551,
#                             "bottom": 365,
#                             "right": 570
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 20
#                 },
#                 "format": {
#                     "name": "QUESTION19",
#                     "value": "QUESTION 19"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "dbe08aa3-8ea4-442d-93cf-b740a36a6f46",
#                 "rois": [
#                     {
#                         "annotationTags": "QUESTION20_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "e553db32-d74c-483a-8ae1-caa39fadc159",
#                         "index": 0,
#                         "rect": {
#                             "top": 378,
#                             "left": 512,
#                             "bottom": 396,
#                             "right": 534
#                         }
#                     },
#                     {
#                         "annotationTags": "QUESTION20_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "ce46cae9-2508-4cda-8e41-3bd578b69b5b",
#                         "index": 1,
#                         "rect": {
#                             "top": 377,
#                             "left": 551,
#                             "bottom": 395,
#                             "right": 571
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 21
#                 },
#                 "format": {
#                     "name": "QUESTION20",
#                     "value": "QUESTION 20"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "98f3dc74-cd8c-49d9-98d1-182edaac4d1a",
#                 "rois": [
#                     {
#                         "annotationTags": "MAX_MARKS_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "96d4f0fd-f32f-420b-b1bd-a8bd5f3ff104",
#                         "index": 0,
#                         "rect": {
#                             "top": 430,
#                             "left": 133,
#                             "bottom": 449,
#                             "right": 156
#                         }
#                     },
#                     {
#                         "annotationTags": "MAX_MARKS_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "bc70b45d-aa14-4364-8d81-a458788d8834",
#                         "index": 1,
#                         "rect": {
#                             "top": 431,
#                             "left": 159,
#                             "bottom": 450,
#                             "right": 181
#                         }
#                     },
#                     {
#                         "annotationTags": "MAX_MARKS_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "7530881e-b396-4c93-bb87-e844b8c62ea9",
#                         "index": 2,
#                         "rect": {
#                             "top": 431,
#                             "left": 185,
#                             "bottom": 451,
#                             "right": 207
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 22
#                 },
#                 "format": {
#                     "name": "MAX_MARKS",
#                     "value": "MAX MARKS"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             },
#             {
#                 "cellId": "667cc2e7-dcda-4416-a166-d295444b0d42",
#                 "rois": [
#                     {
#                         "annotationTags": "MARKS_OBTAINED_1",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "3a169f01-4856-4ce3-831f-9c47a3e9a5f1",
#                         "index": 0,
#                         "rect": {
#                             "top": 430,
#                             "left": 333,
#                             "bottom": 449,
#                             "right": 354
#                         }
#                     },
#                     {
#                         "annotationTags": "MARKS_OBTAINED_2",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "cf8084cf-0299-4414-8b36-468d7659ec00",
#                         "index": 1,
#                         "rect": {
#                             "top": 430,
#                             "left": 358,
#                             "bottom": 448,
#                             "right": 380
#                         }
#                     },
#                     {
#                         "annotationTags": "MARKS_OBTAINED_3",
#                         "extractionMethod": "NUMERIC_CLASSIFICATION",
#                         "roiId": "d8cb645a-7515-41e3-811e-ad6ad777322b",
#                         "index": 2,
#                         "rect": {
#                             "top": 430,
#                             "left": 384,
#                             "bottom": 450,
#                             "right": 405
#                         }
#                     }
#                 ],
#                 "render": {
#                     "index": 23
#                 },
#                 "format": {
#                     "name": "MARKS_OBTAINED",
#                     "value": "MARKS OBTAINED"
#                 },
#                 "validate": {
#                     "regExp": ""
#                 }
#             }
#         ]
#     }
# }
